# %%
import pandas as pd

data = {
    "Age": [20, 25, 30],
    "Experience": [1, 3, 6],
    "Salary": [30000, 50000, 70000]
}

df = pd.DataFrame(data)

df
# Out:
#    Age  Experience  Salary
# 0   20           1   30000
# 1   25           3   50000
# 2   30           6   70000
